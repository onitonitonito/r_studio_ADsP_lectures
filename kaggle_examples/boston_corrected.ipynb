# %%
# -------------------------------------------------------------
# bostonc <- read.table(
#     "http://lib.stat.cmu.edu/datasets/boston_corrected.txt",
#     header=TRUE, sep=",", stringsAsFactors=FALSE,
#     na.strings=c('NIL'), comment.char="#", encoding="UTF-8")
# -------------------------------------------------------------

getwd()
setwd('~/Github/r_studio_ADsP_lectures')
boston <-read.csv("./_static/bostonc_new.csv", header = TRUE, sep = "," )

head(boston); tail(boston)
summary(boston)
# Out:
# [1] "C:/Users/nitt0/Documents/Github/r_studio_ADsP_lectures/kaggle_examples"
#   X OBS. TOWN       TOWN. TRACT LON      LAT     MEDV CMEDV CRIM    ... CHAS
# 1 0 1    Nahant     0     2011  -70.9550 42.2550 24.0 24.0  0.00632 ... 0
# 2 1 2    Swampscott 1     2021  -70.9500 42.2875 21.6 21.6  0.02731 ... 0
# 3 2 3    Swampscott 1     2022  -70.9360 42.2830 34.7 34.7  0.02729 ... 0
# 4 3 4    Marblehead 2     2031  -70.9280 42.2930 33.4 33.4  0.03237 ... 0
# 5 4 5    Marblehead 2     2032  -70.9220 42.2980 36.2 36.2  0.06905 ... 0
# 6 5 6    Marblehead 2     2033  -70.9165 42.3040 28.7 28.7  0.02985 ... 0
#   NOX   RM    AGE  DIS    RAD TAX PTRATIO B      LSTAT
# 1 0.538 6.575 65.2 4.0900 1   296 15.3    396.90 4.98
# 2 0.469 6.421 78.9 4.9671 2   242 17.8    396.90 9.14
# 3 0.469 7.185 61.1 4.9671 2   242 17.8    392.83 4.03
# 4 0.458 6.998 45.8 6.0622 3   222 18.7    394.63 2.94
# 5 0.458 7.147 54.2 6.0622 3   222 18.7    396.90 5.33
# 6 0.458 6.430 58.7 6.0622 3   222 18.7    394.12 5.21
#     X   OBS. TOWN     TOWN. TRACT LON      LAT     MEDV CMEDV CRIM    ... CHAS
# 501 500 501  Revere   90    1708  -70.9920 42.2380 16.8 16.8  0.22438 ... 0
# 502 501 502  Winthrop 91    1801  -70.9860 42.2312 22.4 22.4  0.06263 ... 0
# 503 502 503  Winthrop 91    1802  -70.9910 42.2275 20.6 20.6  0.04527 ... 0
# 504 503 504  Winthrop 91    1803  -70.9948 42.2260 23.9 23.9  0.06076 ... 0
# 505 504 505  Winthrop 91    1804  -70.9875 42.2240 22.0 22.0  0.10959 ... 0
# 506 505 506  Winthrop 91    1805  -70.9825 42.2210 11.9 19.0  0.04741 ... 0
#     NOX   RM    AGE  DIS    RAD TAX PTRATIO B      LSTAT
# 501 0.585 6.027 79.7 2.4982 6   391 19.2    396.90 14.33
# 502 0.573 6.593 69.1 2.4786 1   273 21.0    391.99  9.67
# 503 0.573 6.120 76.7 2.2875 1   273 21.0    396.90  9.08
# 504 0.573 6.976 91.0 2.1675 1   273 21.0    396.90  5.64
# 505 0.573 6.794 89.3 2.3889 1   273 21.0    393.45  6.48
# 506 0.573 6.030 80.8 2.5050 1   273 21.0    396.90  7.88
#        X              OBS.               TOWN         TOWN.         TRACT
#  Min.   :  0.0   Min.   :  1.0   Boston    :132   28     : 30   Hill   : 26
#  1st Qu.:126.2   1st Qu.:127.2   Cambridge : 30   Savin  : 23   Boston : 25
#  Median :252.5   Median :253.5   Lynn      : 22   4      : 22   82     : 19
#  Mean   :252.5   Mean   :253.5   Newton    : 18   Roxbury: 19   84     : 11
#  3rd Qu.:378.8   3rd Qu.:379.8   Somerville: 15   40     : 18   74     :  8
#  Max.   :505.0   Max.   :506.0   Brookline : 12   27     : 15   81     :  8
#                                  (Other)   :277   (Other):379   (Other):409
#       LON               LAT               MEDV            CMEDV
#  Min.   : -71.29   Min.   : -71.10   Min.   :-71.10   Min.   : 7.00
#  1st Qu.: -71.09   1st Qu.:  42.15   1st Qu.: 17.50   1st Qu.:19.30
#  Median : -71.02   Median :  42.23   Median : 22.45   Median :23.05
#  Mean   :  54.18   Mean   : 133.19   Mean   : 12.78   Mean   :26.27
#  3rd Qu.:   7.75   3rd Qu.:  42.30   3rd Qu.: 31.57   3rd Qu.:33.17
#  Max.   :3302.00   Max.   :1404.00   Max.   : 50.00   Max.   :50.00
#
#       CRIM                ZN              INDUS             CHAS
#  Min.   : 0.00632   Min.   :  0.000   Min.   : 0.000   Min.   : 0.000
#  1st Qu.: 0.08249   1st Qu.:  0.000   1st Qu.: 3.417   1st Qu.: 0.000
#  Median : 0.26266   Median :  4.386   Median : 6.200   Median : 0.000
#  Mean   : 4.64889   Mean   : 15.115   Mean   : 8.409   Mean   : 2.141
#  3rd Qu.: 7.20000   3rd Qu.: 20.450   3rd Qu.:10.010   3rd Qu.: 0.000
#  Max.   :50.00000   Max.   :100.000   Max.   :80.000   Max.   :18.100
#
#       NOX               RM             AGE               DIS
#  Min.   : 0.000   Min.   :0.000   Min.   :  0.532   Min.   :  1.322
#  1st Qu.: 0.433   1st Qu.:0.770   1st Qu.:  6.503   1st Qu.:  3.187
#  Median : 0.504   Median :6.006   Median : 43.100   Median :  5.109
#  Mean   : 3.033   Mean   :4.776   Mean   : 45.873   Mean   : 14.297
#  3rd Qu.: 0.605   3rd Qu.:6.511   3rd Qu.: 81.400   3rd Qu.:  6.638
#  Max.   :18.100   Max.   :8.725   Max.   :100.000   Max.   :100.000
#
#       RAD              TAX            PTRATIO            B
#  Min.   :  1.00   Min.   :  1.13   Min.   : 12.6   Min.   : 16.1
#  1st Qu.:  3.00   1st Qu.: 24.00   1st Qu.: 17.4   1st Qu.:377.0
#  Median :  5.00   Median :277.00   Median : 19.1   Median :392.9
#  Mean   : 16.87   Mean   :236.23   Mean   : 94.3   Mean   :379.7
#  3rd Qu.:  6.00   3rd Qu.:329.00   3rd Qu.: 24.0   3rd Qu.:396.9
#  Max.   :100.00   Max.   :711.00   Max.   :666.0   Max.   :666.0
#
#      LSTAT
#  Min.   :  1.73
#  1st Qu.:  7.15
#  Median : 12.04
#  Mean   : 39.42
#  3rd Qu.: 20.20
#  Max.   :396.90

# %%
# ________함수정의 _______________
show_phist <- function(y, x1, x2, data1)  {
  par(mfrow=c(2,2))

  plot( y ~ x1)
  hist(x1)
  #  m1 <- lm(y ~ x1 , data = data1)
  #  abline(m1$coefficients)


  plot( y ~ x2)
  hist(x2)
  #  m2 <- lm(y ~ x2 , data = data1)
  #  abline(m2$coefficients)

  par(mfrow=c(1,1))
}

# %%
y <- boston$MEDV
x1 <- boston$INDUS
x2 <- boston$CRIM

show_phist(log(y), log(x1), log(x2), boston)

plot(boston)
# Out:
# Warning message in log(y):
# "NaN이 생성되었습니다"
# Plot with title "Histogram of x2"
# plot without title
